# %%
import pandas as pd

# %%
import json

# %%
books=pd.read_json("goodreads_books_children.json", lines=True)
books
# Out:
#               isbn  text_reviews_count    series country_code language_code  \
# 0       1599150603                   7        []           US
# 1       1934876569                   6  [151854]           US
# 2       0590417010                 193        []           US           eng
# 3       0915190575                   4        []           US
# 4       1416904999                   4        []           US
# ...            ...                 ...       ...          ...           ...
# 124077                               1        []           US
# 124078                               7        []           US         en-GB
# 124079  0061960314                  13        []           US
# 124080  0689852959                   1        []           US
# 124081  0765197456                   6        []           US
#
#                                           popular_shelves        asin  \
# 0       [{'count': '56', 'name': 'to-read'}, {'count':...
# ...

# %%
temp=books.sort_values('average_rating',ascending=False)[:393]
temp.sort_values('text_reviews_count',ascending=False)[:3]
# Out:
#              isbn  text_reviews_count series country_code language_code  \
# 80815  0988503077                  13     []           US           eng
# 19965  0824919610                  13     []           US
# 19639                              12     []           US
#
#                                          popular_shelves        asin is_ebook  \
# 80815  [{'count': '4', 'name': 'to-read'}, {'count': ...                false
# 19965  [{'count': '272', 'name': 'to-read'}, {'count'...                false
# 19639  [{'count': '13', 'name': 'to-read'}, {'count':...  B014BVDZI2     true
#
#        average_rating kindle_asin  ... publication_month edition_information  \
# 80815             5.0              ...                 9         Large Print
# 19965             5.0              ...                 9
# 19639             5.0  B014BVDZI2  ...
#
#       publication_year                                                url  \
# ...
